# %% [markdown]
# <a href="https://colab.research.google.com/github/sjungmin98/study_data_analytics/blob/main/docs/quests/EDAs/ShoppingMailDeliveryWithDate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### 한글 폰트 설치
# !apt-get install -y fonts-nanum
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 설치 후 colab의 경우 Runtime > Restart session 필요
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 32 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('font', family='NanumBarunGothic') # 혹은 다른 설치한 Nanum 폰트 사용
import pandas as pd
import numpy as np
# 샘플 데이터 생성 (이상치 포함)
df_data = pd.read_csv("ShoppingMallDeliveryWithDate.csv")
df_data[:10]
# Out:
#     결제수단                   배송번호               배송시작일               배송완료일  \
# 0  무통장입금  D-20181227-0000648-00  2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 1  무통장입금  D-20181229-0000119-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 2  무통장입금  D-20181230-0000100-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 3  무통장입금  D-20181231-0000087-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 4  무통장입금  D-20181231-0000108-00  2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 5  무통장입금  D-20181231-0000108-01  2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 6  무통장입금  D-20181231-0000184-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 7  무통장입금  D-20181231-0000184-01  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 8  무통장입금  D-20181231-0000184-02  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 9  무통장입금  D-20181231-0000184-03  2019-01-03 오전 9:30  2019-01-07 오전 5:32
#
#    상품구매금액    상품번호  수량   주문경로       주문일
# 0   71450  1077.0   1  PC쇼핑몰  20181227
# 1  141240    42.0   2   모바일웹  20181229
# 2   13910  1271.0   1   모바일웹  20181230
# 3   81600  1085.0   1   모바일웹  20181231
# 4   94710  1106.0   1   모바일웹  20181231
# 5   75240  1374.0   1   모바일웹  20181231
# 6   82170  1071.0   1  PC쇼핑몰  20181231
# 7   63470  1373.0   1  PC쇼핑몰  20181231
# 8  300960  1374.0   4  PC쇼핑몰  20181231
# 9  121110  1037.0   1  PC쇼핑몰  20181231

# %%
df_data.shape
# Out:
# (46749, 9)

# %% [markdown]
# ## 배송 지연 확인

# %%
delivery_start = df_data['배송시작일'].sort_index()
delivery_start
# Out:
# 0         2019-01-07 오전 8:56
# 1         2019-01-03 오전 9:30
# 2         2019-01-03 오전 9:30
# 3         2019-01-03 오전 9:30
# 4         2019-01-07 오전 8:56
#                 ...
# 46744     2017-12-29 오후 4:32
# 46745     2018-01-03 오전 9:45
# 46746     2018-01-02 오후 7:06
# 46747     2018-01-03 오후 2:00
# 46748    2018-01-03 오후 12:43
# Name: 배송시작일, Length: 46749, dtype: object

# %%
delivery_end = df_data['배송완료일'].sort_index()
delivery_end
# Out:
# 0        2019-01-11 오전 5:32
# 1        2019-01-07 오전 5:32
# 2        2019-01-07 오전 5:32
# 3        2019-01-07 오전 5:32
# 4        2019-01-11 오전 5:32
#                 ...
# 46744    2018-01-02 오전 5:31
# 46745    2018-01-07 오전 5:38
# 46746    2018-01-11 오전 2:46
# 46747    2018-01-06 오후 6:06
# 46748    2018-01-07 오전 5:38
# Name: 배송완료일, Length: 46749, dtype: object

# %%
# '오전'과 '오후'를 'AM'과 'PM'으로 치환
df_data['배송시작일'] = df_data['배송시작일'].str.replace('오전', 'AM').str.replace('오후', 'PM')
df_data['배송완료일'] = df_data['배송완료일'].str.replace('오전', 'AM').str.replace('오후', 'PM')

# %%
# 날짜형으로 변환
df_data['배송시작일'] = pd.to_datetime(df_data['배송시작일'], format='%Y-%m-%d %p %I:%M')
df_data['배송완료일'] = pd.to_datetime(df_data['배송완료일'], format='%Y-%m-%d %p %I:%M')
df_data['배송시작일'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 46749 entries, 0 to 46748
# Series name: 배송시작일
# Non-Null Count  Dtype
# --------------  -----
# 46749 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 365.4 KB

# %%
df_data['배송완료일'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 46749 entries, 0 to 46748
# Series name: 배송완료일
# Non-Null Count  Dtype
# --------------  -----
# 46749 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 365.4 KB

# %%
# 배송시간 계산
df_data['배송시간'] = (df_data['배송완료일'] - df_data['배송시작일']).dt.days
df_data['배송시간']
# Out:
# 0        3
# 1        3
# 2        3
# 3        3
# 4        3
#         ..
# 46744    3
# 46745    3
# 46746    8
# 46747    3
# 46748    3
# Name: 배송시간, Length: 46749, dtype: int64

# %%
# 배송시간을 범주형으로 변환
bins = [0, 2, 4, np.inf]
labels = ['0-2', '2-4', '4+']
df_data['배송시간_확인'] = pd.cut(df_data['배송시간'], bins=bins, labels=labels)
df_data['배송시간_확인']
# Out:
# 0        2-4
# 1        2-4
# 2        2-4
# 3        2-4
# 4        2-4
#         ...
# 46744    2-4
# 46745    2-4
# 46746     4+
# 46747    2-4
# 46748    2-4
# Name: 배송시간_확인, Length: 46749, dtype: category
# Categories (3, object): ['0-2' < '2-4' < '4+']

# %% [markdown]
# ### 배송지연을 5일부터 기준으로 둠

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='배송시간_확인', data=df_data, order=labels)
plt.title('배송시간 별 주문 건수')
plt.xlabel('배송시간 (일)')
plt.ylabel('주문 건수')
plt.show()

# %% [markdown]
# 배송

# %% [markdown]
# ### 무슨 요인으로 배송지연이 되었는지.... 5일이상 걸린 데이터들을 확인해봄

# %%
df_data_delay = df_data[df_data['배송시간_확인'] == '4+'][['결제수단', '상품구매금액', '수량', '주문일']]
df_data_delay
# Out:
#         결제수단  상품구매금액  수량       주문일
# 41        카드   42350   1  20190101
# 47       적립금   68970   1  20190101
# 102       카드  134640   2  20190102
# 106    무통장입금  123420   1  20190102
# 132       카드  388080   3  20190102
# ...      ...     ...  ..       ...
# 46726     카드  118850   1  20171228
# 46737     카드   74000   1  20171228
# 46740     카드   69960   1  20171228
# 46741     카드   63140   1  20171228
# 46746     카드   36000   1  20171230
#
# [2498 rows x 4 columns]

# %% [markdown]
# ##### 1. 결제 수단에 문제가 있나요? No
# ##### 2. 상품 구매가 클수록 배송지연이..? No
# ##### 3. 수량이 많아서 늦나..? No

# %% [markdown]
# ##### 4. 주문일을 살펴보자..시간대를 보아하니 주로.... 휴일이 껴있는것 같아서 좀 더 자세히 살펴봐야겠음

# %%
whatdateis_delayed = df_data_delay['주문일'].unique()
whatdateis_delayed
# Out:
# array([20190101, 20190102, 20190103, 20190104, 20190105, 20190106,
#        20190107, 20190108, 20190109, 20190110, 20190111, 20190113,
#        20190114, 20190115, 20190116, 20190117, 20190118, 20190120,
#        20190121, 20190122, 20190123, 20190124, 20190126, 20190127,
#        20190128, 20190129, 20190130, 20190205, 20190206, 20190207,
#        20190208, 20190209, 20190210, 20190211, 20190212, 20190213,
#        20190214, 20190216, 20190217, 20190219, 20190220, 20190221,
#        20190222, 20190223, 20190224, 20190225, 20190226, 20190227,
#        20190228, 20190301, 20190302, 20190303, 20190304, 20190305,
#        20190306, 20190307, 20190308, 20190309, 20190310, 20190311,
#        20190312, 20190313, 20190314, 20190315, 20190316, 20190317,
#        20190318, 20190319, 20190320, 20190321, 20190322, 20190323,
#        20190324, 20190326, 20190327, 20190328, 20190329, 20190331,
#        20190401, 20190402, 20190403, 20190404, 20190405, 20190406,
#        20190407, 20190408, 20190409, 20190410, 20190411, 20190412,
#        20190413, 20190414, 20190415, 20190416, 20190417, 20190418,
#        20190419, 20190420, 20190421, 20190422, 20190423, 20190424,
#        20190425, 20190426, 20190427, 20190428, 20190429, 20190430,
#        20190501, 20190502, 20190522, 20190523, 20190524, 20190527,
#        20190528, 20190529, 20190530, 20190531, 20190601, 20180102,
#        20180105, 20180106, 20180107, 20180109, 20180115, 20180116,
#        20180117, 20180118, 20180120, 20180122, 20180124, 20180125,
#        20180127, 20180128, 20180129, 20180131, 20180201, 20180202,
#        20180204, 20180205, 20180206, 20180207, 20180210, 20180212,
#        20180214, 20180215, 20180221, 20180223, 20180225, 20180226,
#        20180219, 20180227, 20180301, 20180302, 20180305, 20180306,
#        20180307, 20180309, 20180311, 20180312, 20180315, 20180316,
#        20180318, 20180319, 20180320, 20180321, 20180322, 20180323,
#        20180324, 20180325, 20180326, 20180327, 20180328, 20180329,
#        20180330, 20180331, 20180401, 20180402, 20180403, 20180404,
#        20180405, 20180406, 20180408, 20180409, 20180410, 20180411,
#        20180412, 20180413, 20180414, 20180415, 20180416, 20180417,
#        20180418, 20180419, 20180420, 20180421, 20180422, 20180423,
#        20180424, 20180425, 20180426, 20180427, 20180428, 20180429,
#        20180430, 20180501, 20180502, 20180503, 20180504, 20180507,
#        20180508, 20180509, 20180510, 20180511, 20180512, 20180513,
#        20180514, 20180515, 20180516, 20180517, 20180520, 20180521,
#        20180522, 20180524, 20180525, 20180526, 20180529, 20180530,
#        20180531, 20180601, 20180603, 20180604, 20180605, 20180606,
#        20180607, 20180608, 20180609, 20180610, 20180611, 20180612,
#        20180613, 20180614, 20180615, 20180616, 20180617, 20180618,
#        20180619, 20180620, 20180621, 20180622, 20180624, 20180625,
#        20180626, 20180627, 20180628, 20180630, 20180702, 20180703,
#        20180704, 20180705, 20180706, 20180707, 20180708, 20180709,
#        20180710, 20180711, 20180712, 20180713, 20180714, 20180715,
#        20180716, 20180717, 20180718, 20180719, 20180720, 20180721,
#        20180722, 20180723, 20180724, 20180725, 20180726, 20180727,
#        20180730, 20180731, 20180801, 20180802, 20180803, 20180804,
#        20180805, 20180806, 20180807, 20180808, 20180809, 20180810,
#        20180813, 20180814, 20180815, 20180816, 20180817, 20180819,
#        20180820, 20180821, 20180822, 20180823, 20180824, 20180825,
#        20180827, 20180828, 20180829, 20180830, 20180831, 20180901,
#        20180902, 20180903, 20180904, 20180905, 20180906, 20180908,
#        20180909, 20180910, 20180911, 20180912, 20180913, 20180914,
#        20180916, 20180917, 20180918, 20180919, 20180920, 20180921,
#        20180926, 20180927, 20180928, 20180930, 20181001, 20181002,
#        20181003, 20181004, 20181005, 20181006, 20181008, 20181009,
#        20181010, 20181011, 20181012, 20181013, 20181014, 20181015,
#        20181016, 20181017, 20181018, 20181019, 20181021, 20181022,
#        20181023, 20181024, 20181025, 20181026, 20181027, 20181028,
#        20181029, 20181030, 20181031, 20181101, 20181102, 20181103,
#        20181104, 20181105, 20181106, 20181107, 20181108, 20181109,
#        20181110, 20181111, 20181112, 20181113, 20181114, 20181115,
#        20181116, 20181117, 20181118, 20181119, 20181120, 20181122,
#        20181123, 20181124, 20181125, 20181126, 20181128, 20181129,
#        20181130, 20181202, 20181203, 20181204, 20181205, 20181206,
#        20181207, 20181208, 20181209, 20181210, 20181211, 20181212,
#        20181213, 20181214, 20181215, 20181216, 20181217, 20181218,
#        20181219, 20181220, 20181223, 20181224, 20181225, 20181226,
#        20181227, 20181228, 20181229, 20181230, 20181231, 20170209,
#        20170214, 20170216, 20170228, 20170307, 20170316, 20170317,
#        20170323, 20170324, 20170325, 20170326, 20170327, 20170328,
#        20170330, 20170401, 20170403, 20170404, 20170406, 20170411,
#        20170412, 20170418, 20170420, 20170421, 20170424, 20170426,
#        20170427, 20170430, 20170501, 20170503, 20170504, 20170506,
#        20170509, 20170510, 20170512, 20170514, 20170515, 20170516,
#        20170517, 20170518, 20170519, 20170520, 20170521, 20170522,
#        20170523, 20170524, 20170525, 20170526, 20170527, 20170528,
#        20170529, 20170530, 20170531, 20170601, 20170602, 20170603,
#        20170604, 20170605, 20170606, 20170607, 20170608, 20170609,
#        20170610, 20170611, 20170612, 20170613, 20170614, 20170615,
#        20170616, 20170617, 20170618, 20170619, 20170620, 20170621,
#        20170622, 20170623, 20170624, 20170625, 20170626, 20170627,
#        20170628, 20170629, 20170630, 20170701, 20170702, 20170703,
#        20170705, 20170706, 20170707, 20170708, 20170709, 20170710,
#        20170711, 20170713, 20170714, 20170716, 20170717, 20170718,
#        20170719, 20170720, 20170721, 20170723, 20170724, 20170725,
#        20170726, 20170727, 20170728, 20170729, 20170730, 20170731,
#        20170801, 20170802, 20170803, 20170804, 20170807, 20170808,
#        20170809, 20170810, 20170811, 20170812, 20170813, 20170814,
#        20170815, 20170816, 20170817, 20170818, 20170819, 20170821,
#        20170822, 20170823, 20170824, 20170825, 20170827, 20170828,
#        20170829, 20170830, 20170831, 20170901, 20170902, 20170903,
#        20170904, 20170905, 20170906, 20170907, 20170908, 20170910,
#        20170911, 20170912, 20170913, 20170914, 20170915, 20170916,
#        20170917, 20170918, 20170919, 20170920, 20170921, 20170922,
#        20170923, 20170924, 20170925, 20170926, 20170927, 20170928,
#        20171003, 20171006, 20171007, 20171009, 20171010, 20171011,
#        20171012, 20171013, 20171014, 20171015, 20171016, 20171017,
#        20171018, 20171019, 20171020, 20171021, 20171022, 20171023,
#        20171024, 20171025, 20171026, 20171028, 20171029, 20171030,
#        20171105, 20171108, 20171109, 20171113, 20171115, 20171116,
#        20171117, 20171118, 20171119, 20171120, 20171122, 20171123,
#        20171124, 20171129, 20171201, 20171202, 20171203, 20171204,
#        20171205, 20171207, 20171209, 20171210, 20171211, 20171212,
#        20171213, 20171215, 20171218, 20171220, 20171221, 20171223,
#        20171226, 20171227, 20171228, 20171230])

# %% [markdown]
# 으악 너무 많아요
# 살펴보니 휴일, 공휴일을 끼면 배송이 지연됐음

# %% [markdown]
# - 배송 지연에 대한 해결책
# 1. 휴일 공휴일에 배송할 물량이 쌓이지 않게 다양한 물류회사 컨택
# 2. 자체적으로 회사에서 물류분류관리 체계 도입 (중간단계를 거치지 않아 훨신 빠른 배송 가능)
# 3. 휴일애 근무 가능한 인원 추가
